# %%
# !git clone https://github.com/Belaleatsbanana/nlp.git
# %cd nlp
# Out:
# Cloning into 'nlp'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 66 (delta 1), reused 4 (delta 1), pack-reused 60 (from 1)
# Receiving objects: 100% (66/66), 149.80 MiB | 43.94 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/nlp

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.8/528.8 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 25.4 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=35fe3cea40036c6d73774aaa10fe0657d5d2fbb5743c4c081ad1fc2e6a5091ca
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
# !python eval.py --adapter_dir "yap_finetuned_qwen2.5_adapter" --output_file "results_finetuned_qlora.json" --num_samples 100
# Out:
# [eval] Loading model from yap_finetuned_qwen2.5_adapter…
# ...
# config.json: 100% 660/660 [00:00<00:00, 3.00MB/s]
# model.safetensors: 100% 3.09G/3.09G [00:09<00:00, 342MB/s]
# Loading weights: 100% 338/338 [00:01<00:00, 244.61it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.51MB/s]
# [eval] Loading test set from CSV…
# ...
# 100% 4.95M/4.95M [00:00<00:00, 6.01MB/s]
# Extracting zip of medquad.csv...
# [load_dataset] Dropped 5 rows with missing Q/A.
# [load_dataset] Rows        : 16407
# [eval] Generating answers for 100 samples…
# 100% 100/100 [1:26:02<00:00, 51.63s/it]
# [eval] Computing BERTScore…
# config.json: 100% 792/792 [00:00<00:00, 5.03MB/s]
# tokenizer_config.json: 100% 52.0/52.0 [00:00<00:00, 341kB/s]
# vocab.json: 899kB [00:00, 59.2MB/s]
# merges.txt: 456kB [00:00, 102MB/s]
# pytorch_model.bin: 100% 3.04G/3.04G [00:07<00:00, 389MB/s]
# model.safetensors:   2% 67.1M/3.04G [00:01<00:08, 333MB/s]
# ...

# %%
# !python eval.py --adapter_dir "qwen-medical-adapter-dora" --output_file "results_finetuned_dora.json" --num_samples 100
# Out:
# [eval] Loading model from qwen-medical-adapter-dora…
# ...
# Loading weights: 100% 338/338 [00:01<00:00, 283.55it/s, Materializing param=model.norm.weight]
# [eval] Loading test set from CSV…
# Using Colab cache for faster access to the 'medquad-medical-question-answer-for-ai-research' dataset.
# [load_dataset] Dropped 5 rows with missing Q/A.
# [load_dataset] Rows        : 16407
# [eval] Generating answers for 100 samples…
# 100% 100/100 [2:07:02<00:00, 76.23s/it]
# [eval] Computing BERTScore…
# Loading weights: 100% 772/772 [00:00<00:00, 834.93it/s, Materializing param=encoder.rel_embeddings.weight]
# DebertaModel LOAD REPORT from: microsoft/deberta-xlarge-mnli
# Key                 | Status     |  |
# --------------------+------------+--+-
# classifier.bias     | UNEXPECTED |  |
# classifier.weight   | UNEXPECTED |  |
# pooler.dense.bias   | UNEXPECTED |  |
# pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# ...
